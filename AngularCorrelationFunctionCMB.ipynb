# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = np.loadtxt('ACF_CMB_TREECORR.out', dtype=float)

data[1]
# Out:
# array([1.01490393e-08, 8.82087000e-09, 7.56836287e-09, 6.51242270e-09,
#        5.58311181e-09, 4.73507426e-09, 3.99012642e-09, 3.39621817e-09,
#        2.94869657e-09, 2.62083615e-09, 2.40302724e-09, 2.29988848e-09,
#        2.28058741e-09, 2.27624032e-09, 2.25432331e-09, 2.21545518e-09,
#        2.16773734e-09, 2.11779922e-09, 2.06641538e-09, 2.01777541e-09])

# %%
plt.figure()

plt.plot(data[0],data[1], marker='x')

# %%
plt.figure()

plt.plot(data[0],data[0]*data[1], marker='x')

# %%
data = np.loadtxt('ACF_CMB_TREECORR2.out', dtype = float)

plt.plot(data[0], data[0]*data[1], marker='x')
